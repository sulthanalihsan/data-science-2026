# %% [markdown]
# <a href="https://colab.research.google.com/github/sulthanalihsan/data-science-2026/blob/main/Pertemuan1_Muhamad_Sulthan_Al_Ihsan_250401020154.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World, ini kuliah data Science")
# Out:
# Hello World, ini kuliah data Science

# %%
nama = "Muhammad Sulthan Al Ihsan" # String
angkatan = 2026 # Integer
jurusan = "PJJ-Informatika" #String

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"Jurusan : {jurusan}")
# Out:
# Nama : Muhammad Sulthan Al Ihsan
# Angkatan: 2026
# Jurusan : PJJ-Informatika

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i in tools:
    print(i)
# Out:
# Tools Data Science yang akan kita pelajari:
# Python
# Google Colab
# Jupyter Notebook
# GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Perkenalkan nama saya {nama} dari {prodi}, angkatan {angkatan}, Saya senang belajar python"

perkenalan("Sulthan", "PJJ Informatika", 2026)
# Out:
# 'Hai! Perkenalkan nama saya Sulthan dari PJJ Informatika, angkatan 2026, Saya senang belajar python'
